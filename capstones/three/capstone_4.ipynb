# %% [markdown]
# # Capstone IV: Building a Peer-to-Peer "Teams" Pattern with A2A

# %% [markdown]
# > **Prerequisites:** This capstone assumes you've read **Chapters 2–10**.

# %% [markdown]
# ## Coming soon
#
# Composes `UseA2AAgentTool` and `LLMAgentA2AExecutor` on the same agent, so served agents can also dispatch outward, and coordinates several such peers through a minimal shared task list.
#
# This notebook is a placeholder; the worked capstone has not been written yet.
