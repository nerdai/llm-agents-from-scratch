# %% [markdown]
# # Capstone III: Evaluating MAS vs. Single-Agent Performance

# %% [markdown]
# > **Prerequisites:** This capstone assumes you've read **Chapters 2–10**.

# %% [markdown]
# ## Coming soon
#
# Builds a reusable rubric-and-judge evaluation methodology for comparing a single-agent solution against a MAS decomposition on the same task.
#
# This notebook is a placeholder; the worked capstone has not been written yet.
