# %% [markdown]
# # Capstone V: Graph Engineering with Subagents and A2A Peers

# %% [markdown]
# > **Prerequisites:** This capstone assumes you've read **Chapters 2–10**.

# %% [markdown]
# ## Coming soon
#
# Builds a MAS whose dispatch sequence branches on results rather than following a fixed chain, mixing local subagents and remote A2A peers in the same graph.
#
# This notebook is a placeholder; the worked capstone has not been written yet.
